# %% [markdown]
# #20260417学习笔记
# 今天照着书，让gpt这个老师一边帮我辅助讲解，总算往前顺利啃下去了。
# 尽管进度不算快，但总归这次结结实实的懂了一点，然后继续学。不像之前看天书一样，囫囵吞枣的咽下去，味同嚼蜡，读完还是很迷茫。
#
# 今天学了什么：
# 1. 学会了 Jupyter 的命令模式esc和编辑模式enter
# 2. 完成了 study 分支的第一次 push
# 3. 理解了 print 的“说明 + 结果”结构
#
# 整整学了一天，9:00-12:00,14:00-18:00，这两天都沉浸在python里出不来，有些体会到笑来老师那种遇到自己热爱的事情拔不出来的感觉。
# 学完质数的流程编写，even或odd，接下来该学算法了，太累学不动。今天就到这。
